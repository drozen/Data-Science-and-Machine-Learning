# %%
from IPython.display import HTML# Hide code
HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
import plotly.plotly as py
import plotly.graph_objs as go
#import plotly.tools as tls
#tls.set_credentials_file(username='drozen', api_key='GTP8SX2KBqr3loYdTVb6')

# %%
df = pd.read_csv('data/CC2017.csv')

# %%
df = df[df['Transaction']=='DEBIT'] 
df = df[df['Memo'].notnull()] # remove null entries

# %%
# credit card payments
dfCr = pd.read_csv('data/CC2017.csv')
dfCr = dfCr[dfCr['Transaction']=='CREDIT'] 
dfCR= dfCr[dfCr['Memo'].notnull()] # remove null entries

# %%
dfCr[dfCr['Name']!='PREAUTHORIZED PAYMENT'].sum()[4]  # amount of returns
# Out:
# 2535.68

# %%
dfCr[dfCr['Name']!='PREAUTHORIZED PAYMENT'].head(5)
# Out:
#     Transaction date Transaction                              Name  \
# 8           1/3/2017      CREDIT          HOMESENSE 107 TORONTO ON
# 9           1/3/2017      CREDIT          HOMESENSE 107 TORONTO ON
# 31         1/15/2017      CREDIT  COSTCO WHOLESALE W535 TORONTO ON
# 132        3/19/2017      CREDIT            WINNERS 202 TORONTO ON
# 134        3/19/2017      CREDIT    CARTER'S OSHKOSH #4 TORONTO ON
#
#                                         Memo  Amount
# 8    Rewards earned: -0.17 ~ Category: Other   16.95
# 9    Rewards earned: -0.23 ~ Category: Other   22.59
# 31   Rewards earned: -1.72 ~ Category: Other  171.70
# 132  Rewards earned: -0.28 ~ Category: Other   28.24
# 134  Rewards earned: -0.71 ~ Category: Other   70.56

# %%
dfPay = dfCr[dfCr['Name']=='PREAUTHORIZED PAYMENT']

# %%
dfPay.count()[0]
# Out:
# 11

# %%
dfPay.sum()[4]
# Out:
# 35202.2

# %%
(dfPay.sum()[4] - dfCr[dfCr['Name']!='PREAUTHORIZED PAYMENT'].sum()[4] + 3227.75 - 1320) /12   # total amount spent per month
# Out:
# 2881.1891666666666

# %%
df['Amount'] = df['Amount'].apply(pd.to_numeric, errors='coerce') *-1 #convert to int and convert amounts to positive
df['Transaction date'] = pd.to_datetime(df['Transaction date']) # get date info
df['Month'] = df['Transaction date'].apply(lambda x : x.month)
df['Day'] = df['Transaction date'].apply(lambda x : x.day)
df['Day of Week'] = df['Transaction date'].apply(lambda x : x.dayofweek)
df.head()
# Out:
#   Transaction date Transaction                              Name  \
# 0       2017-01-01       DEBIT  GROUPON CANADA INC 877-788-7858
# 1       2017-01-02       DEBIT  GROUPON CANADA INC 877-788-7858
# 2       2017-01-02       DEBIT  NOFRILLS PATS 1330 NORTH YORK ON
# 3       2017-01-02       DEBIT                     ESSO ORONO ON
# 4       2017-01-03       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
#
#                                          Memo  Amount  Month  Day  Day of Week
# 0      Rewards earned: 0.21 ~ Category: Other   21.00      1    1            6
# 1      Rewards earned: 0.42 ~ Category: Other   42.00      1    2            0
# 2  Rewards earned: 2.46 ~ Category: Groceries  123.07      1    2            0
# 3        Rewards earned: 0.42 ~ Category: Gas   21.04      1    2            0
# 4  Rewards earned: 0.17 ~ Category: Groceries    8.49      1    3            1

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
DayOfWeek = list(map(lambda var: dmap[var],df['Day of Week']))
df['Day of Week'] = DayOfWeek
df.head()
# Out:
#   Transaction date Transaction                              Name  \
# 0       2017-01-01       DEBIT  GROUPON CANADA INC 877-788-7858
# 1       2017-01-02       DEBIT  GROUPON CANADA INC 877-788-7858
# 2       2017-01-02       DEBIT  NOFRILLS PATS 1330 NORTH YORK ON
# 3       2017-01-02       DEBIT                     ESSO ORONO ON
# 4       2017-01-03       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
#
#                                          Memo  Amount  Month  Day Day of Week
# 0      Rewards earned: 0.21 ~ Category: Other   21.00      1    1         Sun
# 1      Rewards earned: 0.42 ~ Category: Other   42.00      1    2         Mon
# 2  Rewards earned: 2.46 ~ Category: Groceries  123.07      1    2         Mon
# 3        Rewards earned: 0.42 ~ Category: Gas   21.04      1    2         Mon
# 4  Rewards earned: 0.17 ~ Category: Groceries    8.49      1    3         Tue

# %% [markdown]
# # Transaction types

# %%
def returnCategory(x):
    return x.split(' ~ Category: ')[1]

def returnName(x):
    return x.split(' ')[0]

# %%
# create category column
df['Category']=df['Memo'].apply(returnCategory)

# create single name column
df['Single Name']=df['Name'].apply(returnName)

df.head()
# Out:
#   Transaction date Transaction                              Name  \
# 0       2017-01-01       DEBIT  GROUPON CANADA INC 877-788-7858
# 1       2017-01-02       DEBIT  GROUPON CANADA INC 877-788-7858
# 2       2017-01-02       DEBIT  NOFRILLS PATS 1330 NORTH YORK ON
# 3       2017-01-02       DEBIT                     ESSO ORONO ON
# 4       2017-01-03       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
#
#                                          Memo  Amount  Month  Day Day of Week  \
# 0      Rewards earned: 0.21 ~ Category: Other   21.00      1    1         Sun
# 1      Rewards earned: 0.42 ~ Category: Other   42.00      1    2         Mon
# 2  Rewards earned: 2.46 ~ Category: Groceries  123.07      1    2         Mon
# 3        Rewards earned: 0.42 ~ Category: Gas   21.04      1    2         Mon
# 4  Rewards earned: 0.17 ~ Category: Groceries    8.49      1    3         Tue
#
#     Category Single Name
# 0      Other     GROUPON
# 1      Other     GROUPON
# 2  Groceries    NOFRILLS
# 3        Gas        ESSO
# 4  Groceries     SAVOURS

# %%
df['Name'].value_counts().head(35)
# Out:
# SAVOURS FRESH MARKET L NORTH YOR    65
# NOFRILLS PATS 1330 NORTH YORK ON    39
# ESSO NORTH YORK ON                  34
# SHOPPERS DRUG MART #08 NORTH YOR    22
# VESTA *CHATR 888-278-5588 BC        21
# COSTCO WHOLESALE W535 TORONTO ON    20
# WAL-MART # 3105 TORONTO ON          15
# URTH FINE FOODS INC NORTH YORK O    13
# DR LAFFA ON THE GO TORONTO ON       12
# METRO #52 NORTH YORK ON             12
# SUN LIFE CHOICES A&A 800-669-792    12
# HERMES BAKERY LTD NORTH YORK ON     11
# KEEPCALLING COM 866-5358095 GA U     9
# ABE'S SERVICE CENTRE NORTH YORK      8
# Amazon *Marketplce CA WWW.AMAZON     8
# FORTINO'S NORTH YORK ON              7
# AROMA BATHUST & WILSON NORTH YOR     7
# TSI INTERNET CHATHAM ON              6
# BAIS YAAKOV ELEMENTARY 416-78361     6
# IKEA NORTH YORK NORTH YORK ON        6
# OLD NAVY CANADA ONLINE BOLTON ON     6
# PAYPAL *NEEMANFOUND 4029357733 O     6
# OLDNAVY.COM 2944 505-462-0076 ON     6
# MASTERMIND- YONGE STRE TORONTO O     5
# BACK IN ACTION NORTH YORK ON         5
# CDN TIRE STORE #00019 NORTH YORK     5
# PETROCAN TORONTO ON                  5
# Amazon.ca AMAZON.CA ON               4
# PETROCAN THORNHILL ON                4
# MIRIAMS GIFT GALLERY TORONTO ON      4
# SLICE N BITES INC NORTH YORK ON      4
# SOX SPOT HATS A LA MOD NORTH YOR     4
# DOLLARAMA # 420 TORONTO ON           4
# DR. SAMUEL AXELROD & A NORTH YOR     4
# KOSHER CITY PLUS NORTH YORK ON       4
# Name: Name, dtype: int64

# %% [markdown]
# # find total Tangerine category (eg. gas) purchases for the year

# %%
df['Memo'].apply(returnCategory).value_counts()
# Out:
# Other               245
# Groceries           153
# Gas                  55
# Restaurant           50
# Bill Payment         45
# Drug Store           31
# Parking              17
# Furniture             9
# Home Improvement      8
# Hotel                 2
# Name: Memo, dtype: int64

# %%
dfCat = df.groupby(['Category','Day of Week']).sum()
dfCatUnstacked = dfCat.unstack()['Amount']

# %%
nameAmtDict = {}
def nameAmt(name, df=df):
    dfCat = df[df['Name'].apply(returnName)==name]
    dfCat = dfCat.apply(pd.to_numeric, errors='coerce') #convert to int
    returnVal = round(dfCat['Amount'].sum()*1,2)
    #print("%.2f" % returnVal)
    return round(returnVal, 2)

# %%
def updateDict(name):
    nameAmtDict[name] = nameAmt(name)

# %%
df['Name'].apply(returnName).value_counts().head(20)
# Out:
# SAVOURS        65
# NOFRILLS       39
# ESSO           38
# SHOPPERS       27
# VESTA          21
# THE            20
# WAL-MART       20
# COSTCO         20
# DR             14
# URTH           13
# METRO          12
# SUN            12
# PETROCAN       11
# HERMES         11
# PAYPAL          9
# KEEPCALLING     9
# Amazon          8
# OLD             8
# ABE'S           8
# DOLLARAMA       7
# Name: Name, dtype: int64

# %%
nameList = ["ABE'S", "PERSONAL", "NOFRILLS", "ESSO", "COSTCO", "WAL-MART", "WINNERS", "CARTER'S", "SAVOURS", "DR", "URTH", "HERMES"]
nameAmtDict = {}
for name in nameList:
    updateDict(name)
nameAmtDict
# Out:
# {"ABE'S": 1852.37,
#  "CARTER'S": 318.99,
#  'COSTCO': 2872.2,
#  'DR': 662.75,
#  'ESSO': 2009.53,
#  'HERMES': 161.76,
#  'NOFRILLS': 4036.14,
#  'PERSONAL': 3507.0,
#  'SAVOURS': 1956.39,
#  'URTH': 203.28,
#  'WAL-MART': 839.1,
#  'WINNERS': 234.36}

# %%
nameList = ["BACK", "BAIS", "SUN", "PREAUTHORIZED"]
nameAmtDict = {}
for name in nameList:
    updateDict(name)
nameAmtDict
# Out:
# {'BACK': 360.0, 'BAIS': 1425.0, 'PREAUTHORIZED': 0.0, 'SUN': 3027.84}

# %%
nameList = ["DR.", "WERB"]  # DR. = Dr Axselrod   Dentists
nameAmtDict = {}
for name in nameList:
    updateDict(name)
nameAmtDict
# Out:
# {'DR.': 278.8, 'WERB': 65.55}

# %%
nameList = ["UNDER", "MARSHALLS", "KALEIDESCOPE"]  # Clothes for work
nameAmtDict = {}
for name in nameList:
    updateDict(name)
nameAmtDict
# Out:
# {'KALEIDESCOPE': 64.98, 'MARSHALLS': 47.24, 'UNDER': 23.72}

# %%
categoryAmtDict = {}
def categoryAmt(category, df=df):
    dfCat = df[df['Memo'].apply(returnCategory)==category]
    dfCat = dfCat.apply(pd.to_numeric, errors='coerce') #convert to int
    returnVal = round(dfCat['Amount'].sum()*1,2)
    print("%.2f" % returnVal)
    return round(returnVal, 2)

# %%
def updateDict(category):
    categoryAmtDict[category] = categoryAmt(category)

# %%
categoryList = df['Memo'].apply(returnCategory).unique()

# %%
categoryList
# Out:
# array(['Other', 'Groceries', 'Gas', 'Bill Payment', 'Drug Store',
#        'Restaurant', 'Home Improvement', 'Furniture', 'Parking', 'Hotel'], dtype=object)

# %%
for cat in categoryList:
    updateDict(cat)
# Out:
# 20451.02
# 7112.79
# 2825.36
# 7398.53
# 688.69
# 1186.69
# 372.66
# 405.30
# 113.07
# 941.00

# %%
categoryAmtDict
# Out:
# {'Bill Payment': 7398.53,
#  'Drug Store': 688.69,
#  'Furniture': 405.3,
#  'Gas': 2825.36,
#  'Groceries': 7112.79,
#  'Home Improvement': 372.66,
#  'Hotel': 941.0,
#  'Other': 20451.02,
#  'Parking': 113.07,
#  'Restaurant': 1186.69}

# %%
D = categoryAmtDict

fig, ax = plt.subplots(figsize=(15, 8))

ax.bar(range(len(D)), D.values(), align='center')
plt.xticks(range(len(D)), list(D.keys()))
plt.title("Spending per Category")
plt.xlabel("Category")
plt.ylabel("Dollars $")
#plt.figure(figsize=(100,100))

plt.show()

# %%
labels=list(D.keys())
values=list(D.values())
trace=go.Pie(labels=labels,values=values)
py.iplot([trace])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~drozen/109.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Find Abes records

# %%
dfAbes = df[df['Name'].apply(lambda x: x.split(' ')[0])=="ABE'S"]

# %%
dfAbes
# Out:
#     Transaction date Transaction                              Name  \
# 23        2017-01-09       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 78        2017-02-14       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 210       2017-05-02       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 229       2017-05-16       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 296       2017-06-22       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 462       2017-09-26       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 476       2017-10-02       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 653       2017-12-28       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
#
#                                        Memo  Amount  Month  Day Day of Week  \
# 23   Rewards earned: 4.53 ~ Category: Other  453.13      1    9         Mon
# 78   Rewards earned: 0.71 ~ Category: Other   71.18      2   14         Tue
# 210  Rewards earned: 0.51 ~ Category: Other  101.70      5    2         Tue
# 229  Rewards earned: 0.17 ~ Category: Other   33.90      5   16         Tue
# 296  Rewards earned: 1.19 ~ Category: Other  237.30      6   22         Thu
# 462  Rewards earned: 0.97 ~ Category: Other  193.54      9   26         Tue
# 476  Rewards earned: 3.30 ~ Category: Other  659.92     10    2         Mon
# 653  Rewards earned: 0.51 ~ Category: Other  101.70     12   28         Thu
#
#     Category Single Name
# 23     Other       ABE'S
# 78     Other       ABE'S
# 210    Other       ABE'S
# 229    Other       ABE'S
# 296    Other       ABE'S
# 462    Other       ABE'S
# 476    Other       ABE'S
# 653    Other       ABE'S

# %%
dfSavours = df[df['Name'].apply(lambda x: x.split(' ')[0])=="SAVOURS"]

# %%
dfSavours
# Out:
#     Transaction date Transaction                              Name  \
# 4         2017-01-03       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 17        2017-01-05       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 20        2017-01-06       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 29        2017-01-11       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 35        2017-01-19       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 47        2017-01-26       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 52        2017-01-31       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 69        2017-02-10       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 79        2017-02-15       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 83        2017-02-17       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 97        2017-02-26       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 118       2017-03-10       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 126       2017-03-16       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 150       2017-03-31       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 163       2017-04-05       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 169       2017-04-07       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 176       2017-04-13       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 181       2017-04-20       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 192       2017-04-25       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 193       2017-04-25       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 200       2017-04-27       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 208       2017-05-02       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 211       2017-05-04       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 218       2017-05-09       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 228       2017-05-16       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 239       2017-05-24       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 244       2017-05-26       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 249       2017-05-28       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 252       2017-05-29       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 256       2017-06-04       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# ..               ...         ...                               ...
# 318       2017-07-06       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 338       2017-07-20       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 354       2017-07-30       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 369       2017-08-07       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 370       2017-08-08       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 396       2017-08-20       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 402       2017-08-27       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 407       2017-08-29       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 416       2017-09-04       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 423       2017-09-07       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 444       2017-09-15       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 454       2017-09-25       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 461       2017-09-26       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 469       2017-09-28       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 484       2017-10-10       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 490       2017-10-15       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 501       2017-10-18       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 502       2017-10-18       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 506       2017-10-19       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 507       2017-10-19       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 524       2017-10-26       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 561       2017-11-16       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 562       2017-11-16       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 576       2017-11-23       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 613       2017-12-07       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 629       2017-12-15       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 630       2017-12-15       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 639       2017-12-20       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 642       2017-12-20       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
# 648       2017-12-25       DEBIT  SAVOURS FRESH MARKET L NORTH YOR
#
#                                            Memo  Amount  Month  Day  \
# 4    Rewards earned: 0.17 ~ Category: Groceries    8.49      1    3
# 17   Rewards earned: 0.11 ~ Category: Groceries    5.61      1    5
# 20   Rewards earned: 0.34 ~ Category: Groceries   16.89      1    6
# 29   Rewards earned: 0.33 ~ Category: Groceries   16.49      1   11
# 35   Rewards earned: 0.86 ~ Category: Groceries   42.76      1   19
# 47   Rewards earned: 0.20 ~ Category: Groceries    9.76      1   26
# 52   Rewards earned: 0.06 ~ Category: Groceries    2.99      1   31
# 69   Rewards earned: 1.00 ~ Category: Groceries   50.14      2   10
# 79   Rewards earned: 0.11 ~ Category: Groceries    5.48      2   15
# 83   Rewards earned: 0.35 ~ Category: Groceries   17.40      2   17
# 97   Rewards earned: 0.18 ~ Category: Groceries    8.99      2   26
# 118  Rewards earned: 0.55 ~ Category: Groceries   27.66      3   10
# 126  Rewards earned: 0.10 ~ Category: Groceries    4.98      3   16
# 150  Rewards earned: 0.55 ~ Category: Groceries   27.43      3   31
# 163  Rewards earned: 2.84 ~ Category: Groceries  141.99      4    5
# 169  Rewards earned: 0.24 ~ Category: Groceries   11.89      4    7
# 176  Rewards earned: 1.42 ~ Category: Groceries   70.93      4   13
# 181  Rewards earned: 1.10 ~ Category: Groceries   54.99      4   20
# 192  Rewards earned: 0.99 ~ Category: Groceries   49.46      4   25
# 193  Rewards earned: 0.41 ~ Category: Groceries   20.51      4   25
# 200  Rewards earned: 1.30 ~ Category: Groceries   64.94      4   27
# 208  Rewards earned: 0.09 ~ Category: Groceries    4.30      5    2
# 211  Rewards earned: 0.07 ~ Category: Groceries    3.49      5    4
# 218  Rewards earned: 0.08 ~ Category: Groceries    3.99      5    9
# 228  Rewards earned: 0.38 ~ Category: Groceries   18.84      5   16
# 239  Rewards earned: 0.77 ~ Category: Groceries   38.39      5   24
# 244  Rewards earned: 0.19 ~ Category: Groceries    9.48      5   26
# 249  Rewards earned: 0.23 ~ Category: Groceries   11.61      5   28
# 252  Rewards earned: 0.65 ~ Category: Groceries   32.40      5   29
# 256  Rewards earned: 1.66 ~ Category: Groceries   82.91      6    4
# ..                                          ...     ...    ...  ...
# 318  Rewards earned: 1.22 ~ Category: Groceries   61.13      7    6
# 338  Rewards earned: 0.97 ~ Category: Groceries   48.53      7   20
# 354  Rewards earned: 0.33 ~ Category: Groceries   16.40      7   30
# 369  Rewards earned: 0.33 ~ Category: Groceries   16.43      8    7
# 370  Rewards earned: 2.68 ~ Category: Groceries  133.78      8    8
# 396  Rewards earned: 1.62 ~ Category: Groceries   81.11      8   20
# 402  Rewards earned: 1.56 ~ Category: Groceries   78.14      8   27
# 407  Rewards earned: 0.22 ~ Category: Groceries   11.14      8   29
# 416  Rewards earned: 1.72 ~ Category: Groceries   86.08      9    4
# 423  Rewards earned: 0.39 ~ Category: Groceries   19.47      9    7
# 444  Rewards earned: 0.51 ~ Category: Groceries   25.39      9   15
# 454  Rewards earned: 0.77 ~ Category: Groceries   38.28      9   25
# 461  Rewards earned: 0.24 ~ Category: Groceries   12.16      9   26
# 469  Rewards earned: 0.90 ~ Category: Groceries   45.05      9   28
# 484  Rewards earned: 0.48 ~ Category: Groceries   23.98     10   10
# 490  Rewards earned: 0.34 ~ Category: Groceries   16.77     10   15
# 501  Rewards earned: 0.78 ~ Category: Groceries   39.05     10   18
# 502  Rewards earned: 0.13 ~ Category: Groceries    6.30     10   18
# 506  Rewards earned: 0.21 ~ Category: Groceries   10.33     10   19
# 507  Rewards earned: 0.40 ~ Category: Groceries   20.23     10   19
# 524  Rewards earned: 0.94 ~ Category: Groceries   47.14     10   26
# 561  Rewards earned: 0.63 ~ Category: Groceries   31.74     11   16
# 562  Rewards earned: 0.09 ~ Category: Groceries    4.28     11   16
# 576  Rewards earned: 0.53 ~ Category: Groceries   26.59     11   23
# 613  Rewards earned: 0.30 ~ Category: Groceries   15.22     12    7
# 629  Rewards earned: 0.21 ~ Category: Groceries   10.60     12   15
# 630  Rewards earned: 0.08 ~ Category: Groceries    3.99     12   15
# 639  Rewards earned: 0.06 ~ Category: Groceries    3.08     12   20
# 642  Rewards earned: 0.28 ~ Category: Groceries   13.76     12   20
# 648  Rewards earned: 0.27 ~ Category: Groceries   13.35     12   25
#
#     Day of Week   Category Single Name
# 4           Tue  Groceries     SAVOURS
# 17          Thu  Groceries     SAVOURS
# 20          Fri  Groceries     SAVOURS
# 29          Wed  Groceries     SAVOURS
# 35          Thu  Groceries     SAVOURS
# 47          Thu  Groceries     SAVOURS
# 52          Tue  Groceries     SAVOURS
# 69          Fri  Groceries     SAVOURS
# 79          Wed  Groceries     SAVOURS
# 83          Fri  Groceries     SAVOURS
# 97          Sun  Groceries     SAVOURS
# 118         Fri  Groceries     SAVOURS
# 126         Thu  Groceries     SAVOURS
# 150         Fri  Groceries     SAVOURS
# 163         Wed  Groceries     SAVOURS
# 169         Fri  Groceries     SAVOURS
# 176         Thu  Groceries     SAVOURS
# 181         Thu  Groceries     SAVOURS
# 192         Tue  Groceries     SAVOURS
# 193         Tue  Groceries     SAVOURS
# 200         Thu  Groceries     SAVOURS
# 208         Tue  Groceries     SAVOURS
# 211         Thu  Groceries     SAVOURS
# 218         Tue  Groceries     SAVOURS
# 228         Tue  Groceries     SAVOURS
# 239         Wed  Groceries     SAVOURS
# 244         Fri  Groceries     SAVOURS
# 249         Sun  Groceries     SAVOURS
# 252         Mon  Groceries     SAVOURS
# 256         Sun  Groceries     SAVOURS
# ..          ...        ...         ...
# 318         Thu  Groceries     SAVOURS
# 338         Thu  Groceries     SAVOURS
# 354         Sun  Groceries     SAVOURS
# 369         Mon  Groceries     SAVOURS
# 370         Tue  Groceries     SAVOURS
# 396         Sun  Groceries     SAVOURS
# 402         Sun  Groceries     SAVOURS
# 407         Tue  Groceries     SAVOURS
# 416         Mon  Groceries     SAVOURS
# 423         Thu  Groceries     SAVOURS
# 444         Fri  Groceries     SAVOURS
# 454         Mon  Groceries     SAVOURS
# 461         Tue  Groceries     SAVOURS
# 469         Thu  Groceries     SAVOURS
# 484         Tue  Groceries     SAVOURS
# 490         Sun  Groceries     SAVOURS
# 501         Wed  Groceries     SAVOURS
# 502         Wed  Groceries     SAVOURS
# 506         Thu  Groceries     SAVOURS
# 507         Thu  Groceries     SAVOURS
# 524         Thu  Groceries     SAVOURS
# 561         Thu  Groceries     SAVOURS
# 562         Thu  Groceries     SAVOURS
# 576         Thu  Groceries     SAVOURS
# 613         Thu  Groceries     SAVOURS
# 629         Fri  Groceries     SAVOURS
# 630         Fri  Groceries     SAVOURS
# 639         Wed  Groceries     SAVOURS
# 642         Wed  Groceries     SAVOURS
# 648         Mon  Groceries     SAVOURS
#
# [65 rows x 10 columns]

# %% [markdown]
# Investigate BillPayment category transactions

# %%
dfBill = df[df['Memo'].apply(returnCategory)=="Bill Payment"]

# %%
dfBill.head(10)
# Out:
#     Transaction date Transaction                              Name  \
# 5         2017-01-03       DEBIT  SUN LIFE CHOICES A&A 800-669-792
# 16        2017-01-04       DEBIT  UBER CA JAN04 WYWLC HE help.uber
# 48        2017-01-26       DEBIT      VESTA *CHATR 888-278-5588 BC
# 55        2017-02-02       DEBIT  SUN LIFE CHOICES A&A 800-669-792
# 82        2017-02-17       DEBIT  PERSONAL INSURANCE COM MISSISSAU
# 96        2017-02-26       DEBIT      VESTA *CHATR 888-278-5588 BC
# 102       2017-03-02       DEBIT  SUN LIFE CHOICES A&A 800-669-792
# 139       2017-03-26       DEBIT      VESTA *CHATR 888-278-5588 BC
# 158       2017-04-04       DEBIT  SUN LIFE CHOICES A&A 800-669-792
# 172       2017-04-08       DEBIT  PERSONAL INSURANCE COM MISSISSAU
#
#                                                Memo   Amount  Month  Day  \
# 5     Rewards earned: 5.05 ~ Category: Bill Payment   252.32      1    3
# 16    Rewards earned: 0.25 ~ Category: Bill Payment    12.67      1    4
# 48    Rewards earned: 0.57 ~ Category: Bill Payment    28.25      1   26
# 55    Rewards earned: 5.05 ~ Category: Bill Payment   252.32      2    2
# 82    Rewards earned: 3.78 ~ Category: Bill Payment   189.00      2   17
# 96    Rewards earned: 0.57 ~ Category: Bill Payment    28.25      2   26
# 102   Rewards earned: 5.05 ~ Category: Bill Payment   252.32      3    2
# 139   Rewards earned: 0.57 ~ Category: Bill Payment    28.25      3   26
# 158   Rewards earned: 5.05 ~ Category: Bill Payment   252.32      4    4
# 172  Rewards earned: 64.12 ~ Category: Bill Payment  3206.00      4    8
#
#     Day of Week      Category Single Name
# 5           Tue  Bill Payment         SUN
# 16          Wed  Bill Payment        UBER
# 48          Thu  Bill Payment       VESTA
# 55          Thu  Bill Payment         SUN
# 82          Fri  Bill Payment    PERSONAL
# 96          Sun  Bill Payment       VESTA
# 102         Thu  Bill Payment         SUN
# 139         Sun  Bill Payment       VESTA
# 158         Tue  Bill Payment         SUN
# 172         Sat  Bill Payment    PERSONAL

# %%
dfOther = df[df['Memo'].apply(returnCategory)=="Other"]

# %%
dfOther.head(80)
# Out:
#     Transaction date Transaction                              Name  \
# 0         2017-01-01       DEBIT  GROUPON CANADA INC 877-788-7858
# 1         2017-01-02       DEBIT  GROUPON CANADA INC 877-788-7858
# 6         2017-01-03       DEBIT        GAP OUTLET 1786 TORONTO ON
# 7         2017-01-03       DEBIT            WINNERS 319 TORONTO ON
# 10        2017-01-03       DEBIT            ARDENE #453 TORONTO ON
# 11        2017-01-03       DEBIT           REITMANS #94 TORONTO ON
# 12        2017-01-03       DEBIT          DYNAMITE #289 TORONTO ON
# 15        2017-01-04       DEBIT   MIRIAMS GIFT GALLERY TORONTO ON
# 18        2017-01-05       DEBIT  DR. SAMUEL AXELROD & A NORTH YOR
# 21        2017-01-08       DEBIT  COSTCO WHOLESALE W535 TORONTO ON
# 23        2017-01-09       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 24        2017-01-09       DEBIT        Udemy San Francisco CA USA
# 32        2017-01-15       DEBIT  COSTCO WHOLESALE W535 TORONTO ON
# 34        2017-01-16       DEBIT         BETH OLOTH 646-6809942 ON
# 36        2017-01-19       DEBIT  DR. SAMUEL AXELROD & A NORTH YOR
# 37        2017-01-21       DEBIT  SP * MOSTLY MUSIC 7184382766 NY
# 38        2017-01-22       DEBIT   OLD NAVY CANADA 3392 TORONTO ON
# 39        2017-01-22       DEBIT   GAP KIDS CANADA 9532 TORONTO ON
# 41        2017-01-22       DEBIT        WAL-MART # 3105 TORONTO ON
# 49        2017-01-29       DEBIT  KEEPCALLING COM 866-5358095 GA U
# 51        2017-01-30       DEBIT  DR LLOYD HOFFMAN DENTI RICHMOND
# 53        2017-02-01       DEBIT  THE CHILDRENS PLACE MISSISSAUGA
# 54        2017-02-01       DEBIT  APL* ITUNES.COM/BILL 800-676-277
# 57        2017-02-05       DEBIT  COSTCO WHOLESALE W535 TORONTO ON
# 59        2017-02-07       DEBIT   ORANGE SQUARE INC NORTH YORK ON
# 60        2017-02-07       DEBIT  MIDRASH SHMUEL TEL9175893004 NY
# 61        2017-02-07       DEBIT  SERVICEONTARIO MIDTOWN TORONTO O
# 62        2017-02-08       DEBIT        WAL-MART # 3105 TORONTO ON
# 65        2017-02-09       DEBIT  COSTCO.CA *ONLINE 800-955-2292 B
# 68        2017-02-10       DEBIT            Amazon.ca AMAZON.CA ON
# ..               ...         ...                               ...
# 146       2017-03-28       DEBIT  MASTERMIND- YONGE STRE TORONTO O
# 147       2017-03-29       DEBIT       UDEMY.COM 8888385432 CA USA
# 148       2017-03-29       DEBIT    123InkCartridges.ca LACHINE QC
# 153       2017-04-03       DEBIT     PETSMART INC. 3030 TORONTO ON
# 154       2017-04-03       DEBIT  THE CHILDREN'S PLACE#3 TORONTO O
# 155       2017-04-03       DEBIT  WINNERSHOMESENSE 20301 VAUGHAN O
# 156       2017-04-03       DEBIT  COSTCO WHOLESALE W535 TORONTO ON
# 157       2017-04-04       DEBIT  SHOE COMPANY # 270 NORTH YORK ON
# 159       2017-04-04       DEBIT            WINNERS 202 TORONTO ON
# 160       2017-04-04       DEBIT  LITTLE SHOE PALACE NORTH YORK ON
# 161       2017-04-05       DEBIT  ZICHRON BINYOMIN CHARI 416-48493
# 164       2017-04-05       DEBIT  LITTLE SHOE PALACE NORTH YORK ON
# 166       2017-04-06       DEBIT   MICROSOFT *STORE MSBILL.INFO ON
# 167       2017-04-06       DEBIT        WAL-MART # 3105 TORONTO ON
# 174       2017-04-10       DEBIT  MASTERMIND- YONGE STRE TORONTO O
# 177       2017-04-14       DEBIT  KEEPCALLING COM 866-5358095 GA U
# 182       2017-04-20       DEBIT  DR. SAMUEL AXELROD & A NORTH YOR
# 183       2017-04-20       DEBIT             INDIGO 286 TORONTO ON
# 184       2017-04-20       DEBIT  COSTCO WHOLESALE W535 TORONTO ON
# 186       2017-04-21       DEBIT  SHOE COMPANY # 270 NORTH YORK ON
# 190       2017-04-23       DEBIT        WAL-MART # 3105 TORONTO ON
# 196       2017-04-26       DEBIT  FRIEDMANS FRESH FISH NORTH YORK
# 202       2017-04-30       DEBIT  COSTCO WHOLESALE W535 TORONTO ON
# 210       2017-05-02       DEBIT  ABE'S SERVICE CENTRE NORTH YORK
# 212       2017-05-05       DEBIT         THE TAX REVIEW TORONTO ON
# 213       2017-05-07       DEBIT        WAL-MART # 3105 TORONTO ON
# 217       2017-05-09       DEBIT  FRIEDMANS FRESH FISH NORTH YORK
# 221       2017-05-12       DEBIT  DR ARASH GHASSABEI DEN TORONTO O
# 223       2017-05-15       DEBIT   THE ISRAELI SOURCE THORNHILL ON
# 225       2017-05-15       DEBIT    AQUARIUM SERVICES THORNHILL ON
#
#                                         Memo   Amount  Month  Day Day of Week  \
# 0     Rewards earned: 0.21 ~ Category: Other    21.00      1    1         Sun
# 1     Rewards earned: 0.42 ~ Category: Other    42.00      1    2         Mon
# 6     Rewards earned: 0.13 ~ Category: Other    12.98      1    3         Tue
# 7     Rewards earned: 0.31 ~ Category: Other    30.51      1    3         Tue
# 10    Rewards earned: 0.15 ~ Category: Other    15.26      1    3         Tue
# 11    Rewards earned: 0.18 ~ Category: Other    18.08      1    3         Tue
# 12    Rewards earned: 0.23 ~ Category: Other    22.60      1    3         Tue
# 15    Rewards earned: 0.36 ~ Category: Other    35.70      1    4         Wed
# 18    Rewards earned: 1.03 ~ Category: Other   103.20      1    5         Thu
# 21    Rewards earned: 1.01 ~ Category: Other   101.48      1    8         Sun
# 23    Rewards earned: 4.53 ~ Category: Other   453.13      1    9         Mon
# 24    Rewards earned: 0.15 ~ Category: Other    15.00      1    9         Mon
# 32    Rewards earned: 0.70 ~ Category: Other    69.52      1   15         Sun
# 34    Rewards earned: 0.18 ~ Category: Other    18.00      1   16         Mon
# 36    Rewards earned: 0.40 ~ Category: Other    39.60      1   19         Thu
# 37    Rewards earned: 0.14 ~ Category: Other    13.55      1   21         Sat
# 38    Rewards earned: 0.03 ~ Category: Other     3.14      1   22         Sun
# 39    Rewards earned: 0.19 ~ Category: Other    18.65      1   22         Sun
# 41    Rewards earned: 0.51 ~ Category: Other    50.55      1   22         Sun
# 49    Rewards earned: 0.05 ~ Category: Other     5.00      1   29         Sun
# 51    Rewards earned: 3.49 ~ Category: Other   349.00      1   30         Mon
# 53    Rewards earned: 0.63 ~ Category: Other    62.88      2    1         Wed
# 54    Rewards earned: 0.01 ~ Category: Other     0.99      2    1         Wed
# 57    Rewards earned: 1.33 ~ Category: Other   133.27      2    5         Sun
# 59    Rewards earned: 0.32 ~ Category: Other    32.24      2    7         Tue
# 60    Rewards earned: 1.45 ~ Category: Other   144.53      2    7         Tue
# 61   Rewards earned: 15.34 ~ Category: Other  1533.60      2    7         Tue
# 62    Rewards earned: 0.42 ~ Category: Other    41.72      2    8         Wed
# 65    Rewards earned: 2.42 ~ Category: Other   241.81      2    9         Thu
# 68    Rewards earned: 0.28 ~ Category: Other    28.19      2   10         Fri
# ..                                       ...      ...    ...  ...         ...
# 146   Rewards earned: 0.09 ~ Category: Other     9.02      3   28         Tue
# 147   Rewards earned: 0.40 ~ Category: Other    40.00      3   29         Wed
# 148   Rewards earned: 0.67 ~ Category: Other    66.74      3   29         Wed
# 153   Rewards earned: 0.09 ~ Category: Other     9.02      4    3         Mon
# 154   Rewards earned: 0.57 ~ Category: Other    56.91      4    3         Mon
# 155   Rewards earned: 0.05 ~ Category: Other     4.51      4    3         Mon
# 156   Rewards earned: 1.31 ~ Category: Other   130.75      4    3         Mon
# 157   Rewards earned: 0.90 ~ Category: Other    90.38      4    4         Tue
# 159   Rewards earned: 1.56 ~ Category: Other   155.89      4    4         Tue
# 160   Rewards earned: 0.66 ~ Category: Other    66.15      4    4         Tue
# 161   Rewards earned: 0.95 ~ Category: Other    95.00      4    5         Wed
# 164   Rewards earned: 0.51 ~ Category: Other    51.45      4    5         Wed
# 166   Rewards earned: 0.05 ~ Category: Other     4.62      4    6         Thu
# 167   Rewards earned: 0.68 ~ Category: Other    67.88      4    6         Thu
# 174   Rewards earned: 0.25 ~ Category: Other    24.76      4   10         Mon
# 177   Rewards earned: 0.05 ~ Category: Other     5.00      4   14         Fri
# 182   Rewards earned: 0.33 ~ Category: Other    33.00      4   20         Thu
# 183   Rewards earned: 0.11 ~ Category: Other    11.29      4   20         Thu
# 184   Rewards earned: 3.55 ~ Category: Other   355.46      4   20         Thu
# 186   Rewards earned: 0.86 ~ Category: Other    86.03      4   21         Fri
# 190   Rewards earned: 0.40 ~ Category: Other    40.41      4   23         Sun
# 196   Rewards earned: 0.03 ~ Category: Other     2.52      4   26         Wed
# 202   Rewards earned: 0.32 ~ Category: Other    63.22      4   30         Sun
# 210   Rewards earned: 0.51 ~ Category: Other   101.70      5    2         Tue
# 212   Rewards earned: 2.26 ~ Category: Other   452.00      5    5         Fri
# 213   Rewards earned: 0.12 ~ Category: Other    24.93      5    7         Sun
# 217   Rewards earned: 0.04 ~ Category: Other     7.82      5    9         Tue
# 221   Rewards earned: 0.18 ~ Category: Other    35.20      5   12         Fri
# 223   Rewards earned: 0.05 ~ Category: Other     9.03      5   15         Mon
# 225   Rewards earned: 0.06 ~ Category: Other    12.42      5   15         Mon
#
#     Category          Single Name
# 0      Other              GROUPON
# 1      Other              GROUPON
# 6      Other                  GAP
# 7      Other              WINNERS
# 10     Other               ARDENE
# 11     Other             REITMANS
# 12     Other             DYNAMITE
# 15     Other              MIRIAMS
# 18     Other                  DR.
# 21     Other               COSTCO
# 23     Other                ABE'S
# 24     Other                Udemy
# 32     Other               COSTCO
# 34     Other                 BETH
# 36     Other                  DR.
# 37     Other                   SP
# 38     Other                  OLD
# 39     Other                  GAP
# 41     Other             WAL-MART
# 49     Other          KEEPCALLING
# 51     Other                   DR
# 53     Other                  THE
# 54     Other                 APL*
# 57     Other               COSTCO
# 59     Other               ORANGE
# 60     Other              MIDRASH
# 61     Other       SERVICEONTARIO
# 62     Other             WAL-MART
# 65     Other            COSTCO.CA
# 68     Other            Amazon.ca
# ..       ...                  ...
# 146    Other          MASTERMIND-
# 147    Other            UDEMY.COM
# 148    Other  123InkCartridges.ca
# 153    Other             PETSMART
# 154    Other                  THE
# 155    Other     WINNERSHOMESENSE
# 156    Other               COSTCO
# 157    Other                 SHOE
# 159    Other              WINNERS
# 160    Other               LITTLE
# 161    Other              ZICHRON
# 164    Other               LITTLE
# 166    Other            MICROSOFT
# 167    Other             WAL-MART
# 174    Other          MASTERMIND-
# 177    Other          KEEPCALLING
# 182    Other                  DR.
# 183    Other               INDIGO
# 184    Other               COSTCO
# 186    Other                 SHOE
# 190    Other             WAL-MART
# 196    Other            FRIEDMANS
# 202    Other               COSTCO
# 210    Other                ABE'S
# 212    Other                  THE
# 213    Other             WAL-MART
# 217    Other            FRIEDMANS
# 221    Other                   DR
# 223    Other                  THE
# 225    Other             AQUARIUM
#
# [80 rows x 10 columns]

# %%
dfOld= dfOther[dfOther['Name'].apply(lambda x: x.split(' ')[0])=="HOMESENSE"]
dfOld.head()
# Out:
#     Transaction date Transaction                      Name  \
# 111       2017-03-07       DEBIT  HOMESENSE 107 TORONTO ON
# 125       2017-03-13       DEBIT  HOMESENSE 107 TORONTO ON
#
#                                        Memo  Amount  Month  Day Day of Week  \
# 111  Rewards earned: 0.34 ~ Category: Other   33.88      3    7         Tue
# 125  Rewards earned: 0.58 ~ Category: Other   57.60      3   13         Mon
#
#     Category Single Name
# 111    Other   HOMESENSE
# 125    Other   HOMESENSE

# %% [markdown]
# # Investigate sums by names

# %%
byName = df.groupby('Name')
byName.sum()
# Out:
#                                    Amount  Month  Day
# Name
# 123InkCartridges.ca LACHINE QC      66.74      3   29
# 3M LAWRENCE PHARMACY NORTH YORK     65.27      1    5
# 407ETR-INTERNET WOODBRIDGE ON        9.82      3   10
# ABE'S SERVICE CENTRE NORTH YORK   1852.37     50  119
# AIR-SERV A 225455 TORONTO ON         1.50      5   15
# AIRBNB * HMN2X2N8KC Trip details   487.00      5   19
# AIRBNB * HMNRBEKA5A Trip details   454.00      5   17
# AISH TANOOR TORONTO ON               3.26      7   28
# APL* ITUNES.COM/BILL 800-676-277    11.98      8    7
# AQUARIUM SERVICES THORNHILL ON      12.42      5   15
# ARDENE #453 TORONTO ON              15.26      1    3
# AROMA BATHUST & WILSON NORTH YOR    77.62     57   95
# Amazon *Marketplce CA WWW.AMAZON   173.28     63   60
# Amazon.ca AMAZON.CA ON              86.45     14   71
# BA-LI LAFFA THORNHILL ON            59.66     12   17
# BACK IN ACTION NORTH YORK ON       360.00     57   89
# BAIS YAAKOV ELEMENTARY 416-78361  1425.00     60   51
# BATH & BODY WORKS #600 TORONTO O   122.04     26   64
# BEST BUY CANADA #927 TORONTO ON    136.44     12   27
# BETH OLOTH 646-6809942 ON           18.00      1   16
# BUBBYS BAGELS NORTH YORK ON          4.51     10   23
# CANADA WIDE PARKING RICHMOND HIL     2.00     18   29
# CANADIAN ASSOCIATION O OTTAWA ON   315.37      9   28
# CARTER'S OSHKOSH #0 ETOBICOKE ON   176.61      4   26
# CARTER'S OSHKOSH #4 TORONTO ON      90.70      4   33
# CARTER'S OSHKOSH THORNHILL ON       51.68      6   16
# CDN TIRE STORE #00006 BARRIE ON      6.77      8   20
# CDN TIRE STORE #00019 NORTH YORK   324.13     36   64
# CHOCOLATE CHARM NORTH YORK ON       19.82     12   12
# COINBASE CHEAPSIDE GBR GBR         152.00     36   33
# ...                                   ...    ...  ...
# THE SHOE COMPANY NORTH YORK ON     168.40     24   43
# THE TAX REVIEW TORONTO ON          452.00      5    5
# TORONTO & REGION CONSE NORTH YOR     7.00      8   29
# TORONTO CHEDER01 OF 01 NORTH YOR   263.00      7   25
# TORONTO PARKING AUTHOR TORONTO O     9.50     19   29
# TOYS R US #3505 THORNHILL ON        25.06      2   12
# TSI INTERNET CHATHAM ON            279.27     59   66
# UBER CA JAN04 WYWLC HE help.uber    12.67      1    4
# UDEMY.COM 8888385432 CA USA         78.00     21   64
# UNDER ARMOUR COOKSTOWN COOKSTOWN    23.72      8   20
# UNDERWRAPS LINGERIE NORTH YORK O    61.02      8   11
# URTH FINE FOODS INC NORTH YORK O   203.28     97  193
# Udemy 1760483369 CA USA             49.00      8   26
# Udemy San Francisco CA USA          15.00      1    9
# VALU MOBILE AT LAWRENC TORONTO O    11.30      8   10
# VESTA *CHATR 888-278-5588 BC       553.70    157  422
# WAL-MART # 3105 TORONTO ON         742.69     86  239
# WAL-MART #3106 TORONTO ON            4.11      1    3
# WAL-MART #5831 THORNHILL ON         92.30     21   62
# WALMART.CA Mississauga ON          192.47     18   54
# WATSON FARMS BOWMANVILLE ON         28.00     10   15
# WERB DENTISTRY TORONTO ON           65.55      8   16
# WIKIMEDIA SAN FRANCISCO CA USA       3.00     12    1
# WINNERS 202 TORONTO ON             203.85     17   33
# WINNERS 319 TORONTO ON              30.51      1    3
# WINNERSHOMESENSE 20301 VAUGHAN O     4.51      4    3
# WMT SUPRCTR #1001 BOWMANVILLE ON    25.24     10   15
# WORLD MILK VARIETY TORONTO ON       22.60     10   10
# YORKDALE TOYOTA PARTS TORONTO ON    35.52      8   16
# ZICHRON BINYOMIN CHARI 416-48493   190.00     15   21
#
# [174 rows x 3 columns]

# %%
df.groupby('Single Name').sum()
# Out:
#                       Amount  Month  Day
# Single Name
# 123InkCartridges.ca    66.74      3   29
# 3M                     65.27      1    5
# 407ETR-INTERNET         9.82      3   10
# ABE'S                1852.37     50  119
# AIR-SERV                1.50      5   15
# AIRBNB                941.00     10   36
# AISH                    3.26      7   28
# APL*                   11.98      8    7
# AQUARIUM               12.42      5   15
# ARDENE                 15.26      1    3
# AROMA                  77.62     57   95
# Amazon                173.28     63   60
# Amazon.ca              86.45     14   71
# BA-LI                  59.66     12   17
# BACK                  360.00     57   89
# BAIS                 1425.00     60   51
# BATH                  122.04     26   64
# BEST                  136.44     12   27
# BETH                   18.00      1   16
# BUBBYS                  4.51     10   23
# CANADA                  2.00     18   29
# CANADIAN              315.37      9   28
# CARTER'S              318.99     14   75
# CDN                   330.90     44   84
# CHOCOLATE              19.82     12   12
# COINBASE              152.00     36   33
# COLLEGE               743.03      5   29
# COSTCO               2872.20    128  270
# COSTCO.CA             241.81      2    9
# D-LITE'S               35.44      2   11
# ...                      ...    ...  ...
# SOBEYS                 52.49      9   51
# SOOTER'S               67.75      7   28
# SOX                    85.58     34   59
# SP                     13.55      1   21
# SQ                     30.48     20   34
# STAPLES                55.30     15   32
# SUN                  3027.84     78   30
# THE                  1172.51    148  301
# TORONTO               279.50     34   83
# TOYS                   25.06      2   12
# TSI                   279.27     59   66
# UBER                   12.67      1    4
# UDEMY.COM              78.00     21   64
# UNDER                  23.72      8   20
# UNDERWRAPS             61.02      8   11
# URTH                  203.28     97  193
# Udemy                  64.00      9   35
# VALU                   11.30      8   10
# VESTA                 553.70    157  422
# WAL-MART              839.10    108  304
# WALMART.CA            192.47     18   54
# WATSON                 28.00     10   15
# WERB                   65.55      8   16
# WIKIMEDIA               3.00     12    1
# WINNERS               234.36     18   36
# WINNERSHOMESENSE        4.51      4    3
# WMT                    25.24     10   15
# WORLD                  22.60     10   10
# YORKDALE               35.52      8   16
# ZICHRON               190.00     15   21
#
# [127 rows x 3 columns]

# %% [markdown]
# ###### Report sums only for purchases > 6

# %%
df.groupby('Single Name').sum()[df.groupby('Single Name').count()['Name']>6]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-42823f2f60cc> in <module>()
# ----> 1 df.groupby('Single Name').sum()[df.groupby('Single Name').count()['Name']>6][0]
#
# C:\Users\danie\Miniconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\danie\Miniconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\danie\Miniconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\danie\Miniconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\danie\Miniconda2\lib\site-packages\pandas\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 0

# %%
dfmean = df.groupby('Single Name').mean()[df.groupby('Single Name').count()['Name']>6]
dfmean.reset_index() #turn index into a column
# Out:
#     Single Name      Amount     Month        Day
# 0         ABE'S  231.546250  6.250000  14.875000
# 1         AROMA   11.088571  8.142857  13.571429
# 2        Amazon   21.660000  7.875000   7.500000
# 3        COSTCO  143.610000  6.400000  13.500000
# 4     DOLLARAMA   17.750000  9.714286  14.571429
# 5            DR   47.339286  6.714286  17.357143
# 6          ESSO   52.882368  6.447368  17.263158
# 7     FORTINO'S   30.390000  7.000000  15.571429
# 8        HERMES   14.705455  6.454545  17.454545
# 9   KEEPCALLING    5.000000  6.222222  21.333333
# 10        METRO   17.005833  7.916667  16.750000
# 11     NOFRILLS  103.490769  6.641026  15.589744
# 12          OLD   58.541250  9.500000  19.250000
# 13       PAYPAL   20.482222  8.444444  20.888889
# 14     PETROCAN   46.761818  4.363636  14.727273
# 15      SAVOURS   30.098308  6.446154  16.876923
# 16     SHOPPERS   20.205926  6.666667  16.518519
# 17          SUN  252.320000  6.500000   2.500000
# 18          THE   58.625500  7.400000  15.050000
# 19         URTH   15.636923  7.461538  14.846154
# 20        VESTA   26.366667  7.476190  20.095238
# 21     WAL-MART   41.955000  5.400000  15.200000

# %%
ax = sns.barplot(x='Single Name', y='Amount',data=dfmean.reset_index(),estimator=sum)

# %% [markdown]
# # BMO Mastercard data

# %%
df1 = pd.read_csv('data/BMO CC2017.csv')
df1.head(15)
# Out:
#     Item #              Card #  Transaction Date  Posting Date  \
# 0        1  '5191230166582263'          20170414      20170417
# 1        2  '5191230166582263'          20170316      20170317
# 2        3  '5191230166582263'          20170317      20170320
# 3        4  '5191230167064154'          20170320      20170320
# 4        5  '5191230167064154'          20170320      20170320
# 5        6  '5191230166582263'          20170326      20170327
# 6        7  '5191230166582263'          20170329      20170329
# 7        8  '5191230166582263'          20170329      20170329
# 8        9  '5191230166582263'          20170330      20170330
# 9       10  '5191230166582263'          20170405      20170405
# 10      11  '5191230166582263'          20170411      20170412
# 11      12  '5191230167064154'          20170219      20170220
# 12      13  '5191230166582263'          20170226      20170227
# 13      14  '5191230166582263'          20170308      20170308
# 14      15  '5191230166582263'          20170311      20170313
#
#     Transaction Amount                            Description
# 0               175.15    CAA SOUTH CENTRAL ON - THORNHILL ON
# 1                30.98  Amazon *Marketplce CA WWW.AMAZON.CAON
# 2                 6.40  Amazon *Marketplce CA WWW.AMAZON.CAON
# 3               -55.13       OLD NAVY CANADA ONLINE BOLTON ON
# 4               -16.06       OLD NAVY CANADA ONLINE BOLTON ON
# 5                39.55           VESTA *CHATR 888-278-5588 BC
# 6                 7.63       Amazon Downloads www.Amazon.caON
# 7                 9.96       Amazon Downloads www.Amazon.caON
# 8                82.58                 Amazon.ca AMAZON.CA ON
# 9              -157.61                AUTOMATIC PYMT RECEIVED
# 10               36.10                TSI INTERNET CHATHAM ON
# 11               81.96       OLD NAVY CANADA ONLINE BOLTON ON
# 12               39.55           VESTA *CHATR 888-278-5588 BC
# 13              -90.59                AUTOMATIC PYMT RECEIVED
# 14               36.10                TSI INTERNET CHATHAM ON

# %% [markdown]
# # Transaction types

# %%
descriptionAmtDict = {}
def descriptionAmt(description, df=df1):
    dfCat = df[df['Description'].apply(returnName)==description]
    dfCat = dfCat.apply(pd.to_numeric, errors='coerce') #convert to int
    returnVal = round(dfCat['Transaction Amount'].sum(),2)
    print("%.2f" % returnVal)
    return round(returnVal, 2)

# %%
def updateDictBMO(description):
    descriptionAmtDict[description] = descriptionAmt(description)

# %%
df1['Description'].value_counts().head(15)
# Out:
# OLD NAVY CANADA ONLINE BOLTON ON         4
# TSI INTERNET CHATHAM ON                  3
# VESTA *CHATR 888-278-5588 BC             3
# AUTOMATIC PYMT RECEIVED                  2
# Amazon *Marketplce CA WWW.AMAZON.CAON    2
# Amazon Downloads www.Amazon.caON         2
# CAA SOUTH CENTRAL ON - THORNHILL ON      1
# Amazon.ca AMAZON.CA ON                   1
# Name: Description, dtype: int64

# %%
df1['Description'].apply(returnName).value_counts().head(15)
# Out:
# OLD          4
# Amazon       4
# VESTA        3
# TSI          3
# AUTOMATIC    2
# CAA          1
# Amazon.ca    1
# Name: Description, dtype: int64

# %%
descriptionList = ["Amazon", "OLD"]

# %%
for description in descriptionList:
    updateDictBMO(description)
# Out:
# 54.97
# 64.38

# %%
descriptionAmtDict
# Out:
# {'Amazon': 54.97, 'OLD': 64.38}

# %%
# Display attribution
HTML('''<script>
  $(document).ready(function(){
    $('div.prompt').hide();
    $('div.back-to-top').hide();
    $('nav#menubar').hide();
    $('.breadcrumb').hide();
    $('.hidden-print').hide();
  });
</script>

<footer id="attribution" style="float:right; color:#999; background:#fff;">
Created with Jupyter, delivered by Daniel Rozen.
</footer>''')
# Out:
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Daniel Rozen.
# </footer>
